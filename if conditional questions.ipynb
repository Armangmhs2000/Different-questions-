# %%
from IPython.display import Image
Image('Questions.PNG')
#to add pictures ,the picture will have to have in same location as ipynb file's location

# %%
l=float(input('enter the value of length: '))
b=float(input('enter the value of breadth: '))
if l==b:
    print('it is square')
else :
    print('it is not square')
# Out:
# it is not square

# %%
n1=int(input('enter the 1st number: '))
n2=int(input('enter the 2nd number: '))
n3=int(input('enter the 3rd number: '))
if n1>n2 and n1>n3 :
    largest=n1
elif n2>n1 and n2>n3 :
   largest=n2
else :
   largest=n3
print('The largest number is ',largest)
# Out:
# The largest number is  4

# %%
held=int(input('enter the number of classes: '))
attended=int(input('enter the number of classes attended: '))
attendedratio=(attended/held)*100
if attendedratio>=75:
    print('allowed to sit in exam')
else:
    print('not allowed')
# Out:
# not allowed

# %%
marks=int(input('enter the marks: '))
if marks<25 :
    print('F grade')
elif marks>=25 and marks<=44 :
    print('E grade')
elif marks>=45 and marks<=49 :
    print('D grade')
elif marks>=50 and marks<=59 :
    print('C grade')
elif marks>=60 and marks<=79 :
    print('B grade')
elif marks>=80 and marks<=89 :
    print('A grade')
else :
    print('A+ grade')
# Out:
# A+ grade
